# %% [markdown]
# Exercise
# Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020
#
# Answer
# 41288.69409442

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("canada_per_capita_income.csv")
dataset.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
dataset.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
plt.xlabel("year")
plt.ylabel("per capita income")
plt.scatter(x=dataset["year"],y=dataset["per capita income (US$)"], c="red" , marker="+")
plt.show()

# %%
new_df1 = dataset.drop("per capita income (US$)" , axis="columns")
new_df2 = dataset["per capita income (US$)"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(new_df1 ,new_df2)
# Out:
# LinearRegression()

# %%
model.predict([[2020]])
# Out:
# C:\Users\prash\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
